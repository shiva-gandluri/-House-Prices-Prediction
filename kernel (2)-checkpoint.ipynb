# %% [markdown]
# <h1> Welcome to my Kernel </h1><br>
#
# I will start this Kernel and will do some updates with new analysis !<br>
#
# I hope you all like this exploration<br>
#
# <h2>About this Dataset</h2><br>
# This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015.
# <br>
# <i>It's a great dataset for evaluating simple regression models.,</i><br>
# <br>

# %%
#source:https://www.kaggle.com/kabure/predicting-house-prices-xgb-rf-bagging-reg-pipe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import scipy.stats as st

# %%
df_usa=(pd.read_csv('C:/Users/Rahul/Downloads/kc_house_data.csv',engine='python'))

# %%
print(df_usa.shape)
print(df_usa.nunique())
# Out:
# (21613, 21)
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %%
print(df_usa.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB
# None

# %%
df_usa.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# Knowning the Price variable

# %%
plt.figure(figsize = (12, 6))

plt.subplot(121)
plt.title('Price Distribuition')
sns.distplot(df_usa['price'])

plt.subplot(122)
g1 = plt.scatter(range(df_usa.shape[0]), np.sort(df_usa.price.values))
g1= plt.title("Price Curve Distribuition", fontsize=15)
g1 = plt.xlabel("")
g1 = plt.ylabel("Amount(US)", fontsize=12)

plt.subplots_adjust(wspace = 0.3, hspace = 0.5,
                    top = 0.9)
plt.show()
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
print("Price Min")
print(df_usa['price'].min())
print("Price Mean")
print(df_usa['price'].mean())
print("Price Median")
print(df_usa['price'].median())
print("Price Max")
print(df_usa['price'].max())
print("Price Std")
print(df_usa['price'].std())
# Out:
# Price Min
# 75000.0
# Price Mean
# 540088.1417665294
# Price Median
# 450000.0
# Price Max
# 7700000.0
# Price Std
# 367127.1964826997

# %%
plt.figure(figsize = (8, 5))
sns.jointplot(df_usa.sqft_living, df_usa.price, 
              alpha = 0.5)
plt.xlabel('Sqft Living')
plt.ylabel('Sale Price')
plt.show()
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Rahul\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
condition = df_usa['condition'].value_counts()

print("Condition counting: ")
print(condition)

fig, ax = plt.subplots(ncols=2, figsize=(14,5))
sns.countplot(x='condition', data=df_usa, ax=ax[0])
sns.boxplot(x='condition', y= 'price',
            data=df_usa, ax=ax[1])
plt.show()
# Out:
# Condition counting:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
plt.figure(figsize = (12,8))
g = sns.FacetGrid(data=df_usa, hue='condition',size= 5, aspect=2)
g.map(plt.scatter, "sqft_living", "price")
plt.show()

# %% [markdown]
# How can I plot this scatter together the graph above using seaborn ???

# %% [markdown]
# <h1>Exploring bathrooms columns by price and conditions

# %%
df_usa["bathrooms"] = df_usa['bathrooms'].round(0).astype(int)

print("Freuency bathroom description:")
print(df_usa["bathrooms"].value_counts())

plt.figure(figsize = (12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

ax1 = plt.subplot(221)
ax1 = sns.countplot(x="bathrooms", data=df_usa,
                    ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
ax1.set_title("Bathrooms counting", fontsize=15)
ax1.set_xlabel("Bathrooms number")
ax1.set_xlabel("count")

ax2 = plt.subplot(222)
ax2 = sns.boxplot(x="bathrooms", y='price',
                  data=df_usa, ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=90)
ax2.set_title("Bathrooms distribution price", fontsize=15)
ax2.set_xlabel("Bathrooms number")
ax2.set_ylabel("log Price(US)")

ax0 = plt.subplot(212)
ax0 = sns.stripplot(x="bathrooms", y="price",
                    data=df_usa, alpha=0.5,
                    jitter=True, hue="condition")
ax0.set_title("Better view distribuition through price", fontsize=15)
ax0.set_xlabel("Bathroom number")
ax0.set_ylabel("log Price(US)")
ax0.set_xticklabels(ax0.get_xticklabels(),rotation=90)

plt.show()
# Out:
# Freuency bathroom description:
# 2    13851
# 1     3933
# 3     2527
# 4     1201
# 5       57
# 6       24
# 0       14
# 8        4
# 7        2
# Name: bathrooms, dtype: int64

# %% [markdown]
# <h2>HOW CAN I SUBPLOTS ONE TYPE OF SCCATER THAT ACCEPTS HUE ??</h2>

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

plt.figure(figsize = (12,6))
ax1 = plt.subplot2grid((2,2), (0,0), colspan = 2)
ax1.set_color_cycle(sns.color_palette('hls', 10))
for val in range(1,6,1):
    indeX = df_usa.condition == val
    ax1.scatter(df_usa.sqft_living.loc[indeX], df_usa.price.loc[indeX], label = val, alpha=0.5)
ax1.legend(bbox_to_anchor = [1.1, 1])
ax1.set_xlabel('sqfit living area')
ax1.set_ylabel('Price house')
ax1.set_title('Sqft Living - Price w.r.t Conditions')

ax2 = plt.subplot2grid((2,2), (1,0))
sns.boxplot(x = 'condition', y = 'price', data = df_usa, ax = ax2)
ax2.set_title('Box Plot Condition & Price', fontsize = 12)

ax3 = plt.subplot2grid((2,2), (1,1))
cubicQual = df_usa.groupby(['condition'])['price'].mean().round(0)
testTrain = df_usa.loc[:, ['condition', 'price']].copy()
testTrain['sqCond'] = np.power(testTrain['condition'],2)
mdl = linear_model.LinearRegression()
mdl.fit(testTrain[['condition', 'sqCond']], testTrain['price'])
y_pred = mdl.predict(testTrain[['condition', 'sqCond']])
print("Mean squared error: %.2f" % mean_squared_error(y_pred, testTrain.price))
# Plot outputs
ax3.scatter(testTrain['condition'], testTrain['price'],  color='black')
ax3.plot(testTrain['condition'], y_pred, color='blue', linewidth=3)
ax3.set_title('LinReg, price ~ condtion + sqft_cond', fontsize = 12)
ax3.set_xlabel('Condition Rate')
plt.subplots_adjust(hspace = 0.5, top = 0.9)
plt.suptitle('Condition Effect to Sale Price', fontsize = 14)
plt.show()
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: The set_color_cycle function was deprecated in version 1.5. Use `.set_prop_cycle` instead.
# Mean squared error: 134582326689.42

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

plt.figure(figsize = (12,6))
ax1 = plt.subplot2grid((2,2), (0,0), colspan = 2)

for val in range(0,5,1):
    indeX = df_usa.view == val
    ax1.scatter(df_usa.sqft_living.loc[indeX], df_usa.price.loc[indeX], label = val, alpha=0.4)
ax1.legend(bbox_to_anchor = [1.1, 1])
ax1.set_xlabel('sqfit living area')
ax1.set_ylabel('Price house')
ax1.set_title('Sqft Living - Price w.r.t View')

ax2 = plt.subplot2grid((2,2), (1,0))
sns.boxplot(x = 'view', y = 'price', data = df_usa, ax = ax2)
ax2.set_title('Box Plot View & Price', fontsize = 12)

ax3 = plt.subplot2grid((2,2), (1,1))
cubicV = df_usa.groupby(['view'])['price'].mean().round(0)
testTrain = df_usa.loc[:, ['view', 'price']].copy()
testTrain['sqview'] = np.power(testTrain['view'],2)
mdl = linear_model.LinearRegression()
mdl.fit(testTrain[['view', 'sqview']], testTrain['price'])
y_pred = mdl.predict(testTrain[['view', 'sqview']])
print("Mean squared error: %.2f" % mean_squared_error(y_pred, testTrain.price))
# Plot outputs
ax3.scatter(testTrain['view'], testTrain['price'],  color='black')
ax3.plot(testTrain['view'], y_pred, color='blue', linewidth=3)
ax3.set_title('LinReg, price ~ condtion + sqft_cond', fontsize = 12)
ax3.set_xlabel('View rate')
plt.subplots_adjust(hspace = 0.5, top = 0.9)
plt.suptitle('"VIEW" Effect To SalePrice', fontsize = 14)
plt.show()
# Out:
# Mean squared error: 112971203793.79

# %%
#How can I color the scatter plot by bedrooms?

# %%
bedrooms = df_usa.bedrooms.value_counts()


plt.figure(figsize = (12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)


ax1 = plt.subplot(221)
ax1 = sns.countplot(x="bedrooms", data=df_usa,
                    ax=ax1)
ax1.set_title("bedrooms counting", fontsize=15)
ax1.set_xlabel("Bathrooms number")
ax1.set_ylabel("count")

ax2 = plt.subplot(222)
ax2 = sns.regplot(x="bedrooms", y='price', 
                  data=df_usa, ax=ax2, x_jitter=True)
ax2.set_title("Bedrooms distribution price", fontsize=15)
ax2.set_xlabel("Bedrooms number")
ax2.set_ylabel("log Price(US)")

ax0 = plt.subplot(212)
ax0 = sns.lvplot(x="bedrooms", y="price",
                    data=df_usa)
ax0.set_title("Better understaning price", fontsize=15)
ax0.set_xlabel("Bedrooms")
ax0.set_ylabel("log Price(US)")

plt.show()

# %%
print("Floors counting description")
print(df_usa['floors'].value_counts())


plt.figure(figsize = (12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

ax1 = plt.subplot(221)
ax1 = sns.lvplot(x="floors", y='price', 
                    data=df_usa, ax=ax1, )
ax1.set_title("Floors counting", fontsize=15)
ax1.set_xlabel("Floors number")
ax1.set_ylabel("Count")

ax2 = plt.subplot(222)
ax2 = sns.countplot(x="floors",
                  data=df_usa, ax=ax2)
ax2.set_title("Floor distribution by price", fontsize=15)
ax2.set_xlabel("Floor number")
ax2.set_ylabel("log Price(US)")

ax0 = plt.subplot(212)
ax0 = sns.regplot(x="floors", y="price", #I need to change floors by sqft_living and hue bye floors
                    data=df_usa, x_jitter=True)
ax0.set_title("Better understaning price by floor", fontsize=15)
ax0.set_xlabel("Floor")
ax0.set_ylabel("log Price(US)")

plt.show()
# Out:
# Floors counting description
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
plt.figure(figsize = (12,8))
g=sns.lmplot(x="sqft_living", y="price", aspect=1.8,
                    data=df_usa, hue="floors", fit_reg=False)
g.set_titles("Floors by sqft_living and price", fontsize=15)
g.set_xlabels("Sqft Living")
g.set_ylabels("Price(US)")
plt.show()

# %%
print("Grade counting description")
print(df_usa['grade'].value_counts())


plt.figure(figsize = (12,8))
plt.subplots_adjust(hspace = 0.4, top = 0.8)

ax1 = plt.subplot(221)
ax1 = sns.lvplot(x="grade", y='price', 
                    data=df_usa, ax=ax1, )
ax1.set_xticklabels(ax1.get_xticklabels(),rotation=90)
ax1.set_title("grade counting", fontsize=15)
ax1.set_xlabel("Grade number")
ax1.set_ylabel("Count")

ax2 = plt.subplot(222)
ax2 = sns.countplot(x="grade",
                  data=df_usa, ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=90)
ax2.set_title("Grade distribution price", fontsize=15)
ax2.set_xlabel("Grade number")
ax2.set_ylabel("log Price(US)")

ax0 = plt.subplot(212)
ax0 = sns.regplot(x="grade", y="price",
                    data=df_usa, x_jitter=True)
ax0.set_title("Better understaning price by grade", fontsize=15)
ax0.set_xlabel("Grade")
ax0.set_ylabel("log Price(US)")
ax0.set_xticklabels(ax0.get_xticklabels(),rotation=90)

plt.show()
# Out:
# Grade counting description
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
#Clearly view of bathrooms and bedrooms correlation

bath = ['bathrooms', 'bedrooms']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[bath[0]], df_usa[bath[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col0 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col1 {
#             background-color:  #e0fce0;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col10 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col11 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col0 {
#             background-color:  #a4dba4;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col1 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col2 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col3 {
#             background-color:  #acdfac;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col4 {
#             background-color:  #d6f7d6;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col5 {
#             background-color:  #d8f8d8;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col6 {
#             background-color:  #d6f7d6;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col7 {
#             background-color:  #d8f8d8;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col10 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col0 {
#             background-color:  #62b662;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col1 {
#             background-color:  #c0eac0;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col2 {
#             background-color:  #42a442;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col3 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col4 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col5 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col6 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col7 {
#             background-color:  #87cb87;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col8 {
#             background-color:  #c0eac0;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col9 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col10 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col11 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row2_col12 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col2 {
#             background-color:  #e0fce0;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col3 {
#             background-color:  #d1f4d1;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col4 {
#             background-color:  #aadeaa;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col5 {
#             background-color:  #3ea23e;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col6 {
#             background-color:  #058205;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col7 {
#             background-color:  #87cb87;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col8 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col9 {
#             background-color:  #4daa4d;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col10 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col11 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row3_col12 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col3 {
#             background-color:  #e0fce0;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col4 {
#             background-color:  #c9efc9;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col5 {
#             background-color:  #7bc47b;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col6 {
#             background-color:  #2e992e;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col7 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col8 {
#             background-color:  #4daa4d;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col9 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col10 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col11 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row4_col12 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col5 {
#             background-color:  #defbde;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col6 {
#             background-color:  #c7eec7;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col7 {
#             background-color:  #caf0ca;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col8 {
#             background-color:  #c0eac0;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col9 {
#             background-color:  #e5ffe5;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col10 {
#             background-color:  #008000;
#         }    #T_4aaf6b8a_1ef6_11e9_813e_b0fc362b96f0row5_col11

# %%
bath_cond = ['bathrooms', 'condition']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[bath_cond[0]], df_usa[bath_cond[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col0 {
#             background-color:  #dbf9db;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col1 {
#             background-color:  #e4fee4;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col0 {
#             background-color:  #008000;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col1 {
#             background-color:  #008000;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col2 {
#             background-color:  #aee0ae;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col3 {
#             background-color:  #95d395;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col4 {
#             background-color:  #a3daa3;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col0 {
#             background-color:  #7ec67e;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col1 {
#             background-color:  #289628;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col2 {
#             background-color:  #008000;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col3 {
#             background-color:  #008000;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col4 {
#             background-color:  #008000;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col1 {
#             background-color:  #d9f8d9;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col2 {
#             background-color:  #bae7ba;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col3 {
#             background-color:  #c3ecc3;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col4 {
#             background-color:  #afe1af;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row4_col2 {
#             background-color:  #cbf1cb;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row4_col3 {
#             background-color:  #dffcdf;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row4_col4 {
#             background-color:  #d8f8d8;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_4d752958_1ef6_11e9_9191_b0fc362b96f0row8_col4 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0" >
# <thead>    <tr>
#         <th class="index_name level0" >condition</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#     </tr>    <tr>
#         <th class="index_name level0" >bathrooms</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col1" class="data row0 col1" >1</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col2" class="data row0 col2" >9</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col3" class="data row0 col3" >3</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row0_col4" class="data row0 col4" >0</td>
#     </tr>    <tr>
#         <th id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col0" class="data row1 col0" >20</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col1" class="data row1 col1" >91</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col2" class="data row1 col2" >2211</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col3" class="data row1 col3" >1300</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row1_col4" class="data row1 col4" >311</td>
#     </tr>    <tr>
#         <th id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col0" class="data row2 col0" >9</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col1" class="data row2 col1" >75</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col2" class="data row2 col2" >9000</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col3" class="data row2 col3" >3702</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row2_col4" class="data row2 col4" >1065</td>
#     </tr>    <tr>
#         <th id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col0" class="data row3 col0" >0</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col1" class="data row3 col1" >5</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col2" class="data row3 col2" >1713</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col3" class="data row3 col3" >553</td>
#         <td id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0row3_col4" class="data row3 col4" >256</td>
#     </tr>    <tr>
#         <th id="T_4d752958_1ef6_11e9_9191_b0fc362b96f0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_4d752958_1e

# %%
bed_cond = ['bedrooms', 'condition']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[bed_cond[0]], df_usa[bed_cond[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col0 {
#             background-color:  #d3f5d3;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col1 {
#             background-color:  #e3fee3;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row1_col0 {
#             background-color:  #99d599;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row1_col1 {
#             background-color:  #c2ebc2;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row1_col2 {
#             background-color:  #e1fde1;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row1_col3 {
#             background-color:  #e2fde2;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row1_col4 {
#             background-color:  #e2fde2;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row2_col0 {
#             background-color:  #008000;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row2_col1 {
#             background-color:  #3ba13b;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row2_col2 {
#             background-color:  #a5dba5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row2_col3 {
#             background-color:  #a9dea9;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row2_col4 {
#             background-color:  #a6dca6;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row3_col0 {
#             background-color:  #4daa4d;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row3_col1 {
#             background-color:  #008000;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row3_col2 {
#             background-color:  #008000;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row3_col3 {
#             background-color:  #008000;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row3_col4 {
#             background-color:  #008000;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row4_col0 {
#             background-color:  #99d599;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row4_col1 {
#             background-color:  #6ebd6e;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row4_col2 {
#             background-color:  #3fa33f;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row4_col3 {
#             background-color:  #57b057;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row4_col4 {
#             background-color:  #2f9a2f;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row5_col1 {
#             background-color:  #e3fee3;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row5_col2 {
#             background-color:  #c1ebc1;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row5_col3 {
#             background-color:  #c2ecc2;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row5_col4 {
#             background-color:  #b6e5b6;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row6_col0 {
#             background-color:  #d3f5d3;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row6_col1 {
#             background-color:  #dcfadc;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row6_col2 {
#             background-color:  #e0fce0;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row6_col3 {
#             background-color:  #defbde;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row6_col4 {
#             background-color:  #defbde;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row11_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row11_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row11_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row11_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row11_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row12_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row12_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row12_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row12_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row12_col4 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0" >
# <thead>    <tr>
#         <th class="index_name level0" >condition</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#     </tr>    <tr>
#         <th class="index_name level0" >bedrooms</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col1" class="data row0 col1" >1</td>
#         <td id="T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col2" class="data row0 col2" >10</td>
#         <td id="T_5037d964_1ef6_11e9_8d3a_b0fc362b96f0row0_col3" class="data row0 col3" >1</td>
#         <td id="T_503

# %%
cond_water = ['condition', 'waterfront']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[cond_water[0]], df_usa[cond_water[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row1_col0 {
#             background-color:  #e4fee4;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row2_col0 {
#             background-color:  #008000;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row2_col1 {
#             background-color:  #008000;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row3_col0 {
#             background-color:  #89cc89;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row3_col1 {
#             background-color:  #68ba68;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row4_col0 {
#             background-color:  #caf0ca;
#         }    #T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row4_col1 {
#             background-color:  #b5e4b5;
#         }</style>
# <table id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0" >
# <thead>    <tr>
#         <th class="index_name level0" >waterfront</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#     </tr>    <tr>
#         <th class="index_name level0" >condition</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row0_col0" class="data row0 col0" >29</td>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row0_col1" class="data row0 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row1_col0" class="data row1 col0" >171</td>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row1_col1" class="data row1 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row2_col0" class="data row2 col0" >13940</td>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row2_col1" class="data row2 col1" >91</td>
#     </tr>    <tr>
#         <th id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row3_col0" class="data row3 col0" >5629</td>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row3_col1" class="data row3 col1" >50</td>
#     </tr>    <tr>
#         <th id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row4_col0" class="data row4 col0" >1681</td>
#         <td id="T_545ec478_1ef6_11e9_9f8a_b0fc362b96f0row4_col1" class="data row4 col1" >20</td>
#     </tr></tbody>
# </table>

# %%
grade_cond = ['grade', 'condition']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[grade_cond[0]], df_usa[grade_cond[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col0 {
#             background-color:  #d1f4d1;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col1 {
#             background-color:  #e3fee3;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row2_col0 {
#             background-color:  #d1f4d1;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row2_col1 {
#             background-color:  #d6f7d6;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row3_col0 {
#             background-color:  #299729;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row3_col1 {
#             background-color:  #b8e6b8;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row3_col2 {
#             background-color:  #e2fde2;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row3_col3 {
#             background-color:  #dffcdf;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row3_col4 {
#             background-color:  #dcfadc;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row4_col0 {
#             background-color:  #008000;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row4_col1 {
#             background-color:  #319b31;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row4_col2 {
#             background-color:  #b8e6b8;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row4_col3 {
#             background-color:  #afe1af;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row4_col4 {
#             background-color:  #a1d9a1;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row5_col0 {
#             background-color:  #68ba68;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row5_col1 {
#             background-color:  #008000;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row5_col2 {
#             background-color:  #008000;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row5_col3 {
#             background-color:  #008000;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row5_col4 {
#             background-color:  #008000;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row6_col0 {
#             background-color:  #bce8bc;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row6_col1 {
#             background-color:  #bee9be;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row6_col2 {
#             background-color:  #2a972a;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row6_col3 {
#             background-color:  #75c175;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row6_col4 {
#             background-color:  #7ac47a;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row7_col1 {
#             background-color:  #e0fce0;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row7_col2 {
#             background-color:  #8cce8c;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row7_col3 {
#             background-color:  #c2ebc2;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row7_col4 {
#             background-color:  #c3ecc3;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row8_col1 {
#             background-color:  #e0fce0;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row8_col2 {
#             background-color:  #bde9bd;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row8_col3 {
#             background-color:  #d9f8d9;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row8_col4 {
#             background-color:  #d7f7d7;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row9_col2 {
#             background-color:  #d7f7d7;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row9_col3 {
#             background-color:  #e1fde1;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row9_col4 {
#             background-color:  #e3fee3;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row10_col2 {
#             background-color:  #e3fee3;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row11_col0 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row11_col1 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row11_col2 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row11_col3 {
#             background-color:  #e5ffe5;
#         }    #T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row11_col4 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0" >
# <thead>    <tr>
#         <th class="index_name level0" >condition</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#         <th class="col_heading level0 col4" >5</th>
#     </tr>    <tr>
#         <th class="index_name level0" >grade</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col1" class="data row0 col1" >0</td>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col2" class="data row0 col2" >0</td>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col3" class="data row0 col3" >0</td>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row0_col4" class="data row0 col4" >0</td>
#     </tr>    <tr>
#         <th id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col0" class="data row1 col0" >0</td>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col1" class="data row1 col1" >1</td>
#         <td id="T_59a013cc_1ef6_11e9_81e9_b0fc362b96f0row1_col2" class="data row1 col2" >1</td>
#         <td id="T_59a013cc_1ef6_11e

# %%
grade_bed = ['grade', 'bedrooms']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[grade_bed[0]], df_usa[grade_bed[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col0 {
#             background-color:  #c0eac0;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col9 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col10 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col11 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row0_col12 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col1 {
#             background-color:  #ddfbdd;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col7 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col9 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col10 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col11 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row1_col12 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col0 {
#             background-color:  #99d599;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col1 {
#             background-color:  #c2ecc2;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col2 {
#             background-color:  #e4fee4;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col9 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col10 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col11 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row2_col12 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col1 {
#             background-color:  #79c379;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col2 {
#             background-color:  #d0f3d0;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col3 {
#             background-color:  #e3fee3;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col4 {
#             background-color:  #e4fee4;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col5 {
#             background-color:  #e4fee4;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col6 {
#             background-color:  #dffcdf;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col7 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col9 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col10 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col11 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row3_col12 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col1 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col2 {
#             background-color:  #48a848;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col3 {
#             background-color:  #bee9be;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col4 {
#             background-color:  #cdf2cd;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col5 {
#             background-color:  #d3f5d3;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col6 {
#             background-color:  #d5f6d5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col7 {
#             background-color:  #d3f5d3;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col9 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col10 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col11 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row4_col12 {
#             background-color:  #e5ffe5;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col0 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col1 {
#             background-color:  #4daa4d;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col2 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col3 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col4 {
#             background-color:  #018001;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col5 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col6 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col7 {
#             background-color:  #138a13;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col8 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col9 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col10 {
#             background-color:  #008000;
#         }    #T_5fccd610_1ef6_11e9_88d4_b0fc362b96f0row5_col11

# %%
grade_bath = ['grade', 'bathrooms']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_usa[grade_bath[0]], df_usa[grade_bath[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col0 {
#             background-color:  #acdfac;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row0_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col0 {
#             background-color:  #72bf72;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row1_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col1 {
#             background-color:  #e3fee3;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col0 {
#             background-color:  #acdfac;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col1 {
#             background-color:  #d0f3d0;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col2 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row3_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col0 {
#             background-color:  #72bf72;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col1 {
#             background-color:  #48a848;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col2 {
#             background-color:  #d1f4d1;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col3 {
#             background-color:  #e1fde1;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col4 {
#             background-color:  #e4fee4;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row4_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col0 {
#             background-color:  #008000;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col1 {
#             background-color:  #008000;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col2 {
#             background-color:  #008000;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col3 {
#             background-color:  #50ac50;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col4 {
#             background-color:  #b2e3b2;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col5 {
#             background-color:  #aadeaa;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row5_col8 {
#             background-color:  #72bf72;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col0 {
#             background-color:  #399f39;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col1 {
#             background-color:  #d6f7d6;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col2 {
#             background-color:  #349d34;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col3 {
#             background-color:  #008000;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col4 {
#             background-color:  #3da23d;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col5 {
#             background-color:  #bee9be;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col6 {
#             background-color:  #b8e6b8;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row6_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col2 {
#             background-color:  #a8dda8;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col3 {
#             background-color:  #42a442;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col4 {
#             background-color:  #158b15;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col5 {
#             background-color:  #c8efc8;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col6 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col7 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row7_col8 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row8_col2 {
#             background-color:  #d4f6d4;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row8_col3 {
#             background-color:  #95d395;
#         }    #T_64c1fe5c_1ef6_11e9_9e51_b0fc362b96f0row8_col4 {
#             bac

# %% [markdown]
# ## Correlation matrix

# %%
corr = df_usa[['bathrooms', 'bedrooms', 'sqft_living', 'sqft_lot', 'floors', 'grade', 'price']]

plt.figure(figsize=(10,8))
plt.title('Correlation of variables')
sns.heatmap(corr.astype(float).corr(),vmax=1.0,  annot=True)
plt.show()

# %% [markdown]
# ## Year built distribuition

# %%
sns.distplot(df_usa['yr_built'])
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
g = sns.factorplot(x="yr_built", y = "price", data=df_usa[df_usa['price'] < 1000000], 
                   size= 7, aspect = 2, kind="box" )
g.set_xticklabels(rotation=90)
plt.show()

# %% [markdown]
# I am trying to incresse the visual of this time

# %%
df_usa = df_usa.merge(pd.get_dummies(df_usa.floors, drop_first=True, prefix='Floors'), left_index=True, right_index=True)
df_usa = df_usa.merge(pd.get_dummies(df_usa.waterfront, drop_first=True, prefix='watFront'), left_index=True, right_index=True)
df_usa = df_usa.merge(pd.get_dummies(df_usa.view, drop_first=True, prefix='View'), left_index=True, right_index=True)
df_usa = df_usa.merge(pd.get_dummies(df_usa.condition, drop_first=True, prefix='Cond'), left_index=True, right_index=True)
df_usa = df_usa.merge(pd.get_dummies(df_usa.grade, prefix='Grade'), left_index=True, right_index=True)
df_usa = df_usa.merge(pd.get_dummies(df_usa.bedrooms, drop_first=True, prefix='Bedrooms'), left_index=True, right_index=True)

# %%
del df_usa['floors'],
del df_usa['waterfront']
del df_usa['view']
del df_usa['condition']
del df_usa['grade']
del df_usa['bedrooms']

# %%
plt.figure(figsize=(15,12))
plt.title('Correlation of variables', fontsize=20)
sns.heatmap(df_usa.corr().astype(float).corr(),vmax=1.0)
plt.show()

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score # to split the data
from sklearn.metrics import explained_variance_score, median_absolute_error, r2_score, mean_squared_error, accuracy_score, confusion_matrix, classification_report, fbeta_score #To evaluate our model

from sklearn.grid_search import GridSearchCV
# Out:
# C:\Users\Rahul\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\Rahul\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
########################################################
######## IMPORTING NECESSARY MODULES AND MODELS ########
########################################################

from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split # Model evaluation
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler # Preprocessing
from sklearn.linear_model import Lasso, Ridge, ElasticNet, RANSACRegressor, SGDRegressor, HuberRegressor, BayesianRidge # Linear models
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, AdaBoostRegressor, GradientBoostingRegressor, ExtraTreesRegressor  # Ensemble methods
from xgboost import XGBRegressor, plot_importance # XGBoost
from sklearn.svm import SVR, SVC, LinearSVC  # Support Vector Regression
from sklearn.tree import DecisionTreeRegressor # Decision Tree Regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline # Streaming pipelines
from sklearn.decomposition import KernelPCA, PCA # Dimensionality reduction
from sklearn.feature_selection import SelectFromModel # Dimensionality reduction
from sklearn.model_selection import learning_curve, validation_curve, GridSearchCV # Model evaluation
from sklearn.base import clone # Clone estimator
from sklearn.metrics import mean_squared_error as MSE

# %%
df_usa.drop(['id', 'date'], axis=1, inplace=True)
X = df_usa.drop("price",axis=1).values
y = df_usa["price"].values

# %%
# Spliting X and y into train and test version
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=3)

# %% [markdown]
# ### Selecting the most important features

# %%
thresh = 5 * 10**(-3)
model = XGBRegressor()
model.fit(X_train, y_train)
#select features using threshold
selection = SelectFromModel(model, threshold=thresh, prefit=True)
select_X_train = selection.transform(X_train)
# eval model
select_X_val = selection.transform(X_test)
# test 
select_X_test = selection.transform(X_test)

# %% [markdown]
# ### Creating the pipeline with the models to we do a first evaluate of their power to this problem

# %%
pipelines = []
seed = 2

pipelines.append(
                ("Scaled_Ridge", 
                 Pipeline([
                     ("Scaler", StandardScaler()), 
                     ("Ridge", Ridge(random_state=seed, tol=10 ))
                      ]))
                )
pipelines.append(
                ("Scaled_Lasso", 
                 Pipeline([
                     ("Scaler", StandardScaler()), 
                     ("Lasso", Lasso(random_state=seed, tol=1))
                      ]))
                )
pipelines.append(
                ("Scaled_Elastic", 
                 Pipeline([
                     ("Scaler", StandardScaler()), 
                     ("Lasso", ElasticNet(random_state=seed))
                      ]))
                )

pipelines.append(
                ("Scaled_SVR",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("SVR",  SVR(kernel='linear', C=1e2, degree=5))
                 ])
                )
                )

pipelines.append(
                ("Scaled_RF_reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("RF", RandomForestRegressor(random_state=seed))
                 ])
                )
                )

pipelines.append(
                ("Scaled_ET_reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("ET", ExtraTreesRegressor(random_state=seed))
                 ])
                )
                )
pipelines.append(
                ("Scaled_BR_reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("BR", BaggingRegressor(random_state=seed))
                 ]))) 

pipelines.append(
                ("Scaled_Hub-Reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("Hub-Reg", HuberRegressor())
                 ]))) 
pipelines.append(
                ("Scaled_BayRidge",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("BR", BayesianRidge())
                 ]))) 

pipelines.append(
                ("Scaled_XGB_reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("XGBR", XGBRegressor(seed=seed))
                 ]))) 

pipelines.append(
                ("Scaled_DT_reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("DT_reg", DecisionTreeRegressor())
                 ]))) 

pipelines.append(
                ("Scaled_KNN_reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("KNN_reg", KNeighborsRegressor())
                 ])))
#pipelines.append(
#                ("Scaled_ADA-Reg",
#                 Pipeline([
#                     ("Scaler", StandardScaler()),
#                     ("ADA-reg", AdaBoostRegressor())
#                 ]))) 

pipelines.append(
                ("Scaled_Gboost-Reg",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("GBoost-Reg", GradientBoostingRegressor())
                 ])))

pipelines.append(
                ("Scaled_RFR_PCA",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("PCA", PCA(n_components=3)),
                     ("XGB", RandomForestRegressor())
                 ])))

pipelines.append(
                ("Scaled_XGBR_PCA",
                 Pipeline([
                     ("Scaler", StandardScaler()),
                     ("PCA", PCA(n_components=3)),
                     ("XGB", XGBRegressor())
                 ])))

#'neg_mean_absolute_error', 'neg_mean_squared_error','r2'
scoring = 'r2'
n_folds = 7

results, names  = [], [] 

for name, model  in pipelines:
    kfold = KFold(n_splits=n_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, cv= kfold,
                                 scoring=scoring, n_jobs=-1)    
    names.append(name)
    results.append(cv_results)    
    msg = "%s: %f (+/- %f)" % (name, cv_results.mean(),  cv_results.std())
    print(msg)
    
# boxplot algorithm comparison
fig = plt.figure(figsize=(15,6))
fig.suptitle('Algorithm Comparison', fontsize=22)
ax = fig.add_subplot(111)
sns.boxplot(x=names, y=results)
ax.set_xticklabels(names)
ax.set_xlabel("Algorithmn Name", fontsize=20)
ax.set_ylabel("R Squared Score of Models", fontsize=18)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
plt.show()
# Out:
# Scaled_Ridge: 0.727431 (+/- 0.009924)
# Scaled_Lasso: 0.683566 (+/- 0.013035)
# Scaled_Elastic: 0.700632 (+/- 0.009749)
# Scaled_SVR: 0.671598 (+/- 0.009346)
# Scaled_RF_reg: 0.850280 (+/- 0.013045)
# Scaled_ET_reg: 0.858379 (+/- 0.015712)
# Scaled_BR_reg: 0.847568 (+/- 0.013438)
# Scaled_Hub-Reg: 0.701841 (+/- 0.009565)
# Scaled_BayRidge: 0.727563 (+/- 0.009940)
# Scaled_XGB_reg: 0.856188 (+/- 0.006032)
# Scaled_DT_reg: 0.725738 (+/- 0.038172)
# Scaled_KNN_reg: 0.716625 (+/- 0.020929)
# Scaled_Gboost-Reg: 0.857892 (+/- 0.007684)
# Scaled_RFR_PCA: 0.610814 (+/- 0.017415)
# Scaled_XGBR_PCA: 0.655817 (+/- 0.017960)

# %% [markdown]
# Very cool results!
#
# We can see that we got good models with a good r2 score.
#
# >All RandomForestRegression, ExtraTreesRgressor, BaggingRegressor and XGBRegressor have r2 higher than 0.80
#
# I will set hyper parameters to the best models and try increase this score

# %% [markdown]
# ## Testing the best models
#
# ### Startig by XGBREgressor

# %%
xgb = XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
xgb.fit(X_train, y_train)

# %%
y_hat = xgb.predict(X_test)

# %%
xgb.score(X_test,y_test)

# %% [markdown]
# Excellent result of XGB Regressor with some arbitrary params.
#
# Now, let's explore the Random Search in RandomForest Regressor

# %% [markdown]
# ### Randominzed Search in RandomForest Regressor
#
# - first I will set the params grid to use on Randomized Search

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 200, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %% [markdown]
# ## Using Random Search to find the best Hyper Paramns

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed: 11.0min

# %%
#Knowning the best params
rf_random.best_params_

# %%
# Predicting with best params
y_hat_Search = rf_random.predict(X_test)

# %% [markdown]
# ## Printing the difference between the 2 models scores

# %%
print("XGBoost Regressor R2-score: {}".format(round(r2_score(y_hat, y_test),4)))
print("RandomForest Regressor Prediction R2-score: {}".format(round(r2_score(y_hat_Search, y_test),4)))
print("\nMSE of XGBoost Regressor: {}".format(median_absolute_error(y_hat, y_test)))
print("MSE of RandomForest Regressor: {} ".format(median_absolute_error(y_hat_Search, y_test)))

# %% [markdown]
# ## Stay Tuned! I will keep finding the model and hyper parameters to this problem
#
# Please votes up if you liked my Kernel =)
